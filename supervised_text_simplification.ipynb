# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pprint
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
BASE_DIR = "/content/drive/My Drive/UCU/Diploma/supervised_text_simplification"
MODEL_DIR = f"{BASE_DIR}/training"

# os.environ['VOCAB_SOURCE'] = f"{BASE_DIR}/wikilarge_small/train/vocab.sources.txt"
# os.environ['VOCAB_TARGET'] = f"{BASE_DIR}/wikilarge_small/train/vocab.targets.txt"
# os.environ['TRAIN_SOURCES'] = f"{BASE_DIR}/wikilarge_small/train/sources.txt"
# os.environ['TRAIN_TARGETS'] = f"{BASE_DIR}/wikilarge_small/train/targets.txt"
# os.environ['DEV_SOURCES'] = f"{BASE_DIR}/wikilarge_small/dev/sources.txt"
# os.environ['DEV_TARGETS'] = f"{BASE_DIR}/wikilarge_small/dev/targets.txt"
# os.environ['DEV_TARGETS_REF'] = f"{BASE_DIR}/wikilarge_small/dev/targets.txt"

os.environ['VOCAB_SOURCE'] = f"{BASE_DIR}/wikilarge/train/vocab.sources.txt"
os.environ['VOCAB_TARGET'] = f"{BASE_DIR}/wikilarge/train/vocab.targets.txt"
os.environ['TRAIN_SOURCES'] = f"{BASE_DIR}/wikilarge/train/sources.txt"
os.environ['TRAIN_TARGETS'] = f"{BASE_DIR}/wikilarge/train/targets.txt"
os.environ['DEV_SOURCES'] = f"{BASE_DIR}/wikilarge/dev/sources.txt"
os.environ['DEV_TARGETS'] = f"{BASE_DIR}/wikilarge/dev/targets.txt"
os.environ['DEV_TARGETS_REF'] = f"{BASE_DIR}/wikilarge/dev/targets.txt"

os.environ['NMT_CONFIGS'] = f"{BASE_DIR}/configs"
os.environ['MODEL_DIR'] = MODEL_DIR
os.environ['PRED_DIR'] = f"{MODEL_DIR}/pred"

# %%
# %env TRAIN_STEPS = 14000
# Out:
# env: TRAIN_STEPS=14000

# %%
# %cd "/content/drive/My Drive/UCU/Diploma/supervised_text_simplification/seq2seq"
# Out:
# /content/drive/My Drive/UCU/Diploma/supervised_text_simplification/seq2seq

# %%
# !chmod 777 train.sh

# %%
# !./train.sh
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/UCU/Diploma/supervised_text_simplification/seq2seq/seq2seq/training/hooks.py:44: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/UCU/Diploma/supervised_text_simplification/seq2seq/seq2seq/training/hooks.py:296: The name tf.train.GlobalStepWaiterHook is deprecated. Please use tf.estimator.GlobalStepWaiterHook instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
# !mkdir -p "$PRED_DIR"

# %%
# %%bash
#
# python -m bin.infer \
#   --tasks "
#     - class: DecodeText" \
#   --model_dir "$MODEL_DIR" \
#   --input_pipeline "
#     class: ParallelTextInputPipeline
#     params:
#       source_files:
#         - $DEV_SOURCES" \
#   >  "${PRED_DIR}"/predictions.txt
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/UCU/Diploma/supervised_text_simplification/seq2seq/seq2seq/training/hooks.py:44: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/UCU/Diploma/supervised_text_simplification/seq2seq/seq2seq/training/hooks.py:296: The name tf.train.GlobalStepWaiterHook is deprecated. Please use tf.estimator.GlobalStepWaiterHook instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
if 'COLAB_TPU_ADDR' not in os.environ:
  print('ERROR: Not connected to a TPU runtime')
else:
  tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  print ('TPU address is', tpu_address)

  with tf.Session(tpu_address) as session:
    devices = session.list_devices()
    
  print('TPU devices:')
  pprint.pprint(devices)
# Out:
# TPU address is grpc://10.16.166.162:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 14803100040275647408),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 2603204364085174092),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 11122527799894939038),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 5001208547305384591),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 11448235608257194777),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 11499676307134432514),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 755279743463072975),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 18401435881805472254),
# ...
